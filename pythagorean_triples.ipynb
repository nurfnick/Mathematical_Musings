# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Mathematical_Musings/blob/main/pythagorean_triples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
pyth = []

for i in range(1,100):
  for j in range(i+1,10000):
    k = math.sqrt(i**2+j**2)
    if k.is_integer():
      pyth.append([i,j,int(k)])

# %%
pyth
# Out:
# [[3, 4, 5],
#  [5, 12, 13],
#  [6, 8, 10],
#  [7, 24, 25],
#  [8, 15, 17],
#  [9, 12, 15],
#  [9, 40, 41],
#  [10, 24, 26],
#  [11, 60, 61],
#  [12, 16, 20],
#  [12, 35, 37],
#  [13, 84, 85],
#  [14, 48, 50],
#  [15, 20, 25],
#  [15, 36, 39],
#  [15, 112, 113],
#  [16, 30, 34],
#  [16, 63, 65],
#  [17, 144, 145],
#  [18, 24, 30],
#  [18, 80, 82],
#  [19, 180, 181],
#  [20, 21, 29],
#  [20, 48, 52],
#  [20, 99, 101],
#  [21, 28, 35],
#  [21, 72, 75],
#  [21, 220, 221],
#  [22, 120, 122],
#  [23, 264, 265],
#  [24, 32, 40],
#  [24, 45, 51],
#  [24, 70, 74],
#  [24, 143, 145],
#  [25, 60, 65],
#  [25, 312, 313],
#  [26, 168, 170],
#  [27, 36, 45],
#  [27, 120, 123],
#  [27, 364, 365],
#  [28, 45, 53],
#  [28, 96, 100],
#  [28, 195, 197],
#  [29, 420, 421],
#  [30, 40, 50],
#  [30, 72, 78],
#  [30, 224, 226],
#  [31, 480, 481],
#  [32, 60, 68],
#  [32, 126, 130],
#  [32, 255, 257],
#  [33, 44, 55],
#  [33, 56, 65],
#  [33, 180, 183],
#  [33, 544, 545],
#  [34, 288, 290],
# ...

# %%
20**2+21**2
# Out:
# 841

# %%
29**2
# Out:
# 841
